# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>

# %% [markdown]
# # Introduction
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# **What?** Simple ETL pipeline

# %% [markdown]
# # What is an ETL pipeline?
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# - An ETL (Data Extraction, Transformation, Loading) pipeline is a set of processes used to Extract, Transform, and Load data from a source to a target.
#
# - The source of the data can be from one or many sources, such as from an API call, CSV files, information within a database, and many more.
#
# - We take these sources of information then transform it in a way where it can be used immediately by another client, user or developer within some target storage.
#
# - **ETL vs. data pipeline** ETL pipelines qualify as a type of data pipeline. But “data pipeline” is a more general term, and a data pipeline does not necessarily involve data transformation or even loading into a destination database—the loading process in a data pipeline could activate another process or workflow, for instance.

# %% [markdown]
# # Import modules
# <hr style = "border:2px solid black" ></hr>

# %%
import requests
import pandas as pd
import numpy as np
import os
import sqlite3
from tqdm.auto import tqdm

# %% [markdown]
#  # Extraction
#  <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# - We'll be collecting raw data from John Hopkins University’s [GitHub](https://github.com/CSSEGISandData/COVID-19).
# - Specifically we will be looking at the daily reports.
# - From Github’s API documentation, we can send a GET request to this endpoint to receive a JSON response back telling us the urls for each csv file so we can read directly.
# - `OWNER` is owner of GitHub repository
# - `REPO` is name of repository
# - `PATH` is specific path to our folder we want to examine relative to REPO
# - `URL` is api endpoint used to send GET request

# %%
OWNER = 'CSSEGISandData'
REPO = 'COVID-19'
PATH = 'csse_covid_19_data/csse_covid_19_daily_reports'
URL = f'https://api.github.com/repos/{OWNER}/{REPO}/contents/{PATH}'
print(f'Downloading paths from {URL}')
# Out:
# Downloading paths from https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports

# %%
download_urls = []
response = requests.get(URL)

# %%
response.json()
# Out:
# [{'name': '.gitignore',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/.gitignore',
#   'sha': '496ee2ca6a2f08396a4076fe43dedf3dc0da8b6d',
#   'size': 9,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/.gitignore?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/.gitignore',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/496ee2ca6a2f08396a4076fe43dedf3dc0da8b6d',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/.gitignore',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/.gitignore?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/496ee2ca6a2f08396a4076fe43dedf3dc0da8b6d',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/.gitignore'}},
#  {'name': '01-01-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-01-2021.csv',
#   'sha': '80aef65f1db81337ab0a12eea7eda3641e3addf3',
#   'size': 569510,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-01-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-01-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/80aef65f1db81337ab0a12eea7eda3641e3addf3',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-01-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-01-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/80aef65f1db81337ab0a12eea7eda3641e3addf3',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-01-2021.csv'}},
#  {'name': '01-01-2022.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-01-2022.csv',
#   'sha': 'd382c8fe2a36502bb652c349c57dac61a0990b0c',
#   'size': 558729,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-01-2022.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-01-2022.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/d382c8fe2a36502bb652c349c57dac61a0990b0c',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-01-2022.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-01-2022.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/d382c8fe2a36502bb652c349c57dac61a0990b0c',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-01-2022.csv'}},
#  {'name': '01-02-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-02-2021.csv',
#   'sha': '25e384934edf5bc3cb70c7ecdd7915be029b271e',
#   'size': 569741,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-02-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-02-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/25e384934edf5bc3cb70c7ecdd7915be029b271e',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-02-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-02-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/25e384934edf5bc3cb70c7ecdd7915be029b271e',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-02-2021.csv'}},
#  {'name': '01-02-2022.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-02-2022.csv',
#   'sha': '7b30cd5f37742a05f44d42ac3d6466d8625c20da',
#   'size': 558553,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-02-2022.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-02-2022.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/7b30cd5f37742a05f44d42ac3d6466d8625c20da',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-02-2022.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-02-2022.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/7b30cd5f37742a05f44d42ac3d6466d8625c20da',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-02-2022.csv'}},
#  {'name': '01-03-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-03-2021.csv',
#   'sha': 'cfcd2458373dd2fcfd17311d8af6b51442ca18e1',
#   'size': 569914,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-03-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-03-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/cfcd2458373dd2fcfd17311d8af6b51442ca18e1',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-03-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-03-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/cfcd2458373dd2fcfd17311d8af6b51442ca18e1',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-03-2021.csv'}},
#  {'name': '01-03-2022.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-03-2022.csv',
#   'sha': '6083185f66bad89a66a35329b5dc6bcc6e1c6afd',
#   'size': 558761,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-03-2022.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-03-2022.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/6083185f66bad89a66a35329b5dc6bcc6e1c6afd',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-03-2022.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-03-2022.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/6083185f66bad89a66a35329b5dc6bcc6e1c6afd',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-03-2022.csv'}},
#  {'name': '01-04-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-04-2021.csv',
#   'sha': '331efb67d961ad12e3ea19c444c426e292ff94a8',
#   'size': 569925,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-04-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-04-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/331efb67d961ad12e3ea19c444c426e292ff94a8',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-04-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-04-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/331efb67d961ad12e3ea19c444c426e292ff94a8',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-04-2021.csv'}},
#  {'name': '01-04-2022.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-04-2022.csv',
#   'sha': '29b76554b4315628dd16a5a20c88f4760bc1de76',
#   'size': 558848,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-04-2022.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-04-2022.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/29b76554b4315628dd16a5a20c88f4760bc1de76',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-04-2022.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-04-2022.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/29b76554b4315628dd16a5a20c88f4760bc1de76',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-04-2022.csv'}},
#  {'name': '01-05-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-05-2021.csv',
#   'sha': '63de049ef61319e39aeba7f640e684a395f0c16a',
#   'size': 570100,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-05-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-05-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/63de049ef61319e39aeba7f640e684a395f0c16a',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-05-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-05-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/63de049ef61319e39aeba7f640e684a395f0c16a',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-05-2021.csv'}},
#  {'name': '01-05-2022.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-05-2022.csv',
#   'sha': '218fa13e9877d50444cb6fa7a19d7a686a01e984',
#   'size': 558882,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-05-2022.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-05-2022.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/218fa13e9877d50444cb6fa7a19d7a686a01e984',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-05-2022.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-05-2022.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/218fa13e9877d50444cb6fa7a19d7a686a01e984',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-05-2022.csv'}},
#  {'name': '01-06-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-06-2021.csv',
#   'sha': 'c1a6e66b09d59208261705c5b8b0d87c853549e8',
#   'size': 570110,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-06-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-06-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/c1a6e66b09d59208261705c5b8b0d87c853549e8',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-06-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-06-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/c1a6e66b09d59208261705c5b8b0d87c853549e8',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-06-2021.csv'}},
#  {'name': '01-06-2022.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-06-2022.csv',
#   'sha': 'dcd0295f19c0967966b6f4c95a732a34ba0866a0',
#   'size': 558884,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-06-2022.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-06-2022.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/dcd0295f19c0967966b6f4c95a732a34ba0866a0',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-06-2022.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-06-2022.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/dcd0295f19c0967966b6f4c95a732a34ba0866a0',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-06-2022.csv'}},
#  {'name': '01-07-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/01-07-2021.csv',
#   'sha': 'd4951483a31bc14ff22e6c30895cd4c3a96c3845',
#   'size': 570141,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-07-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-07-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/d4951483a31bc14ff22e6c30895cd4c3a96c3845',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-07-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/01-07-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs
csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/12-26-2020.csv',
#   'sha': '9d1d71c5d59fe3d2a9b829e8ecd15ba7bc66e26c',
#   'size': 569283,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-26-2020.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-26-2020.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/9d1d71c5d59fe3d2a9b829e8ecd15ba7bc66e26c',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/12-26-2020.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-26-2020.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/9d1d71c5d59fe3d2a9b829e8ecd15ba7bc66e26c',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-26-2020.csv'}},
#  {'name': '12-26-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/12-26-2021.csv',
#   'sha': 'a8158aca1d7124c24588ae36d5146e2ebf00c4b0',
#   'size': 558528,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-26-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-26-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/a8158aca1d7124c24588ae36d5146e2ebf00c4b0',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/12-26-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-26-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/a8158aca1d7124c24588ae36d5146e2ebf00c4b0',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-26-2021.csv'}},
#  {'name': '12-27-2020.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/12-27-2020.csv',
#   'sha': '18d4818f192660289c7c8930d2d939f66d7cc706',
#   'size': 569272,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-27-2020.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-27-2020.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/18d4818f192660289c7c8930d2d939f66d7cc706',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/12-27-2020.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-27-2020.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/18d4818f192660289c7c8930d2d939f66d7cc706',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-27-2020.csv'}},
#  {'name': '12-27-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/12-27-2021.csv',
#   'sha': 'ab17cb56790fc4cc5ebe775cab00a6e2ab4547c2',
#   'size': 558543,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-27-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-27-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/ab17cb56790fc4cc5ebe775cab00a6e2ab4547c2',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/12-27-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-27-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/ab17cb56790fc4cc5ebe775cab00a6e2ab4547c2',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-27-2021.csv'}},
#  {'name': '12-28-2020.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/12-28-2020.csv',
#   'sha': '9a262b2eddc0ff42cf240ef01318df7973ab3031',
#   'size': 569326,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-28-2020.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-28-2020.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/9a262b2eddc0ff42cf240ef01318df7973ab3031',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/12-28-2020.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-28-2020.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/9a262b2eddc0ff42cf240ef01318df7973ab3031',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-28-2020.csv'}},
#  {'name': '12-28-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/12-28-2021.csv',
#   'sha': '737ef2272433e7522de17ce0afdd3e2fd8db33e2',
#   'size': 558649,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-28-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-28-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/737ef2272433e7522de17ce0afdd3e2fd8db33e2',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/12-28-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-28-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/737ef2272433e7522de17ce0afdd3e2fd8db33e2',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-28-2021.csv'}},
#  {'name': '12-29-2020.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/12-29-2020.csv',
#   'sha': '77fc8f932deb88f855a1997e18a7e8970854374f',
#   'size': 569493,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-29-2020.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-29-2020.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/77fc8f932deb88f855a1997e18a7e8970854374f',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/12-29-2020.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-29-2020.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/77fc8f932deb88f855a1997e18a7e8970854374f',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-29-2020.csv'}},
#  {'name': '12-29-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/12-29-2021.csv',
#   'sha': 'd71cbff0709147fb3f19c88da8ae50da42ce628e',
#   'size': 558652,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-29-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-29-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/d71cbff0709147fb3f19c88da8ae50da42ce628e',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/12-29-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-29-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/d71cbff0709147fb3f19c88da8ae50da42ce628e',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-29-2021.csv'}},
#  {'name': '12-30-2020.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/12-30-2020.csv',
#   'sha': '3a3982c158d2c76f3b7827f49dfda86b749142b7',
#   'size': 569502,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-30-2020.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-30-2020.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/3a3982c158d2c76f3b7827f49dfda86b749142b7',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/12-30-2020.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-30-2020.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/3a3982c158d2c76f3b7827f49dfda86b749142b7',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-30-2020.csv'}},
#  {'name': '12-30-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/12-30-2021.csv',
#   'sha': 'a78c5185a3e887488afd728536a8029f28dcd66d',
#   'size': 558657,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-30-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-30-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/a78c5185a3e887488afd728536a8029f28dcd66d',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/12-30-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-30-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/a78c5185a3e887488afd728536a8029f28dcd66d',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-30-2021.csv'}},
#  {'name': '12-31-2020.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/12-31-2020.csv',
#   'sha': '6a85493cc77e1b3751e733a5f1a26f2af288571e',
#   'size': 569519,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-31-2020.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-31-2020.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/6a85493cc77e1b3751e733a5f1a26f2af288571e',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/12-31-2020.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-31-2020.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/6a85493cc77e1b3751e733a5f1a26f2af288571e',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-31-2020.csv'}},
#  {'name': '12-31-2021.csv',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/12-31-2021.csv',
#   'sha': 'df7f8a3ebc4cbde2f67ccac33da7b7dcf32fa118',
#   'size': 558729,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-31-2021.csv?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-31-2021.csv',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/df7f8a3ebc4cbde2f67ccac33da7b7dcf32fa118',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/12-31-2021.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/12-31-2021.csv?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/df7f8a3ebc4cbde2f67ccac33da7b7dcf32fa118',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-31-2021.csv'}},
#  {'name': 'README.md',
#   'path': 'csse_covid_19_data/csse_covid_19_daily_reports/README.md',
#   'sha': 'e69de29bb2d1d6434b8b29ae775ad8c2e48c5391',
#   'size': 0,
#   'url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/README.md?ref=master',
#   'html_url': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/README.md',
#   'git_url': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391',
#   'download_url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/README.md',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/CSSEGISandData/COVID-19/contents/csse_covid_19_data/csse_covid_19_daily_reports/README.md?ref=master',
#    'git': 'https://api.github.com/repos/CSSEGISandData/COVID-19/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391',
#    'html': 'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/README.md'}}]

# %% [markdown]
# - Using Python’s Requests library we will interpret the JSON response and examine the information we need.
#
# - What is returned is an array of object descriptions for every file in the github repo. We are interested in the ‘download_url’. We will use this ‘download_url’ to download this data directly using Pandas then transform it as we see fit.
#
# - The script below collects all the `download_url`’s into a Python List Object

# %%
for data in tqdm(response.json()):
    if data['name'].endswith('.csv'):
        download_urls.append(data['download_url'])
# Out:
#   0%|          | 0/775 [00:00<?, ?it/s]

# %%
pd.DataFrame(download_urls)
# Out:
#                                                      0
# 0    https://raw.githubusercontent.com/CSSEGISandDa...
# 1    https://raw.githubusercontent.com/CSSEGISandDa...
# 2    https://raw.githubusercontent.com/CSSEGISandDa...
# 3    https://raw.githubusercontent.com/CSSEGISandDa...
# 4    https://raw.githubusercontent.com/CSSEGISandDa...
# ..                                                 ...
# 768  https://raw.githubusercontent.com/CSSEGISandDa...
# 769  https://raw.githubusercontent.com/CSSEGISandDa...
# 770  https://raw.githubusercontent.com/CSSEGISandDa...
# 771  https://raw.githubusercontent.com/CSSEGISandDa...
# 772  https://raw.githubusercontent.com/CSSEGISandDa...
#
# [773 rows x 1 columns]

# %% [markdown]
# # Transform
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# - Taking a look at the information, we are interested in looking at specific values. If these values are not within the DataFrame, we will replace/add these columns with Empty values (such as numpy.nan).
#
# - Some labels are inconsistent. They define the same type of data, but they are named differently. For example, ‘Last Update’ is also called ‘Last_Update’. We will also redefine these labels for consistency.
#
# - The code above transform the already collected data as a Pandas DataFrame add makes the DataFrames consistent by adding and relabelling columns.

# %%
# List of labels to be renamed
relabel = {
    # 'Last Update': 'Last_Update',
    'Country/Region': 'Country_Region',
    'Lat': 'Latitude',
    'Long_': 'Longitude',
    'Province/State': 'Province_State',
}

# %%
def factor_dataframe(dat, filename):
    """ Refactor the dataframe to be uploaded into a SQL database
    as a pandas DataFrame
    """
    # rename labels
    for label in dat:
        if label in relabel:
            dat = dat.rename(columns={label: relabel[label]})

    # return a dataframe with these parameters
    labels = ['Province_State', 'Country_Region',
              'Last_Update', 'Confirmed', 'Deaths', 'Recovered']
    # filename is datetime
    if 'Last_Update' not in dat:
        dat['Last_Update'] = pd.to_datetime(filename)

    # replace columns not in dataframe with nan
    for label in labels:
        if label not in dat:
            dat[label] = np.nan

    return dat[labels]

# %% [markdown]
# # Load
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# - We can directly load our pandas DataFrame into a SQL database using `pandas.DataFrame.to_sql`.
#
# - If the table within the database has already created, replace it with a new one. This is a very bad way to do this in production. But for the simplicity of this exercise it suffices.
#
# - The code below describes how to connect to a SQLite database using sqlite3.

# %%
def upload_to_sql(filenames, db_name, debug=False):
    """ Given a list of paths, upload to a database
    """
    
    conn = sqlite3.connect(f"{db_name}.db")

    if debug:
        print("Uploading into database")
    for i, file_path in tqdm(list(enumerate(filenames))):

        dat = pd.read_csv(file_path)

        # rename labels
        filename = os.path.basename(file_path).split('.')[0]
        dat = factor_dataframe(dat, filename)

        # write records to sql database
        if i == 0:  # if first entry, and table name already exist, replace
            dat.to_sql(db_name, con=conn, index=False, if_exists='replace')
        else:  # otherwise append to current table given db_name
            dat.to_sql(db_name, con=conn, index=False, if_exists='append')

# %% [markdown]
# # Run ETL pipeline and clean up
# <hr style = "border:2px solid black" ></hr>

# %%
# upload into sql database
upload_to_sql(download_urls, 'example', debug=True)
# Out:
# Uploading into database
#   0%|          | 0/773 [00:00<?, ?it/s]

# %%
# Check is database was saved locally
# !ls
# Out:
# Simple ETL pipeline.ipynb example.db

# %%
# Delete database
! rm example.db

# %% [markdown]
# # References
# <hr style = "border:2px solid black" ></hr>

# %% [markdown]
# - https://medium.com/analytics-vidhya/building-a-etl-pipeline-226656a22f6d
# - [COVID-19 Data Repository by the Center for Systems Science and Engineering (CSSE) at Johns Hopkins University](https://github.com/CSSEGISandData/COVID-19)
# - From Github’s API documentation, we can send a GET request to this endpoint to receive a JSON response back telling us the urls for each csv file so we can read directly.
